# %%
import pandas as pd
import matplotlib.pyplot as plt
# 차트에 한글 깨지지 않도록 차트 폰트변경
plt.rcParams['font.family'] = 'Malgun Gothic'
# 차트에 "-"문자 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
# 막대 차트를 그리기 위해 필요한 데이터셋
df = pd.Series([7, 10], index=["M", "F"])
df.plot(kind="bar")

# 실제 제공되는 데이터 셋
gender = pd.Series([
    "M", "F", "M", "M", "F",
    "M", "F", "M", "M", "F",
    "M", "F", "M", "M", "F",
    "M", "M"
])

# 데이터셋 변경 후 차트를 그려야 한다.
gender.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
s= gender.value_counts()
s.plot(kind="pie")
# Out:
# <Axes: >

# %%
df = pd.DataFrame([
    {"이름": "김민수", "성별": "남", "나이": 23},
    {"이름": "이영희", "성별": "여", "나이": 25},
    {"이름": "박철수", "성별": "남", "나이": 27},
    {"이름": "최지영", "성별": "여", "나이": 24},
    {"이름": "정우진", "성별": "남", "나이": 31},
    {"이름": "강수진", "성별": "여", "나이": 29},
    {"이름": "윤현우", "성별": "남", "나이": 35},
    {"이름": "한지민", "성별": "여", "나이": 26},
    {"이름": "조성호", "성별": "남", "나이": 42},
    {"이름": "서유진", "성별": "여", "나이": 33},
    {"이름": "임재현", "성별": "남", "나이": 38},
    {"이름": "오수민", "성별": "여", "나이": 30},
    {"이름": "장동현", "성별": "남", "나이": 45},
    {"이름": "배지은", "성별": "여", "나이": 28},
    {"이름": "신준호", "성별": "남", "나이": 52},
    {"이름": "문소연", "성별": "여", "나이": 36},
    {"이름": "권혁준", "성별": "남", "나이": 8},
    {"이름": "노은지", "성별": "여", "나이": 41},
    {"이름": "홍길동", "성별": "남", "나이": 75},
    {"이름": "김하늘", "성별": "남", "나이": 32}
])

df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      20 non-null     str
#  1   성별      20 non-null     str
#  2   나이      20 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 612.0 bytes
#               나이
# count  20.000000
# mean   34.000000
# std    13.459491
# min     8.000000
# 25%    26.750000
# 50%    31.500000
# 75%    38.750000
# max    75.000000

# %%
df["나이"].describe()
# Out:
# count    20.000000
# mean     34.000000
# std      13.459491
# min       8.000000
# 25%      26.750000
# 50%      31.500000
# 75%      38.750000
# max      75.000000
# Name: 나이, dtype: float64

# %%
df["성별"].describe()
s= df.value_counts()
type(s)
# Out:
# pandas.Series

# %%
df["나이"].plot(kind="hist",bins=8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["나이"].plot(kind="box")
# Out:
# <Axes: >

# %%
# 직원 데이터 생성
df = pd.DataFrame({
    '사번': [
        'E001', 'E002', 'E003', 'E004', 'E005',
        'E006', 'E007', 'E008', 'E009', 'E010',
        'E011', 'E012', 'E013', 'E014', 'E015',
        'E016', 'E017', 'E018', 'E019', 'E020',
        'E021', 'E022'
    ],

    '이름': [
        '김민수', '이영희', '박철수', '최지영', '정수진',
        '강현우', '윤서연', '한준호', '오지훈', '서민지',
        '임성호', '장유진', '조현우', '배수빈', '문지훈',
        '신예은', '권도윤', '황지민', '송준혁', '김서현',
        '이도현', '박유나'
    ],

    '부서': [
        '개발팀', '마케팅팀', '개발팀', '인사팀', '영업팀',
        '개발팀', '마케팅팀', '영업팀', '개발팀', '인사팀',
        '영업팀', '개발팀', '마케팅팀', '영업팀', '개발팀',
        '인사팀', '마케팅팀', '개발팀', '영업팀', '개발팀',
        '마케팅팀', '인사팀'
    ],

    '성별': [
        '남', '여', '남', '여', '여',
        '남', '여', '남', '남', '여',
        '남', '여', '남', '여', '남',
        '여', '남', '여', '남', '여',
        '남', '여'
    ],

    '나이': [
        28, 31, 26, 35, 29,
        42, 27, 33, 30, 38,
        45, 25, 34, 29, 41,
        32, 36, 28, 39, 27,
        44, 30
    ],

    '연봉': [
        4200, 5100, 3900, 5800, 4500,
        7200, 4100, 5600, 4700, 6300,
        8100, 3800, 5900, 4400, 6900,
        5200, 6100, 4300, 6700, 4000,
        7600, 4800
    ],

    '근속년수': [
        3, 5, 2, 8, 4,
        15, 2, 7, 5, 11,
        18, 1, 6, 3, 14,
        6, 9, 3, 12, 2,
        16, 5
    ],

    '평가등급': [
        'A', 'B', 'A', 'C', 'B',
        'A', 'B', 'A', 'C', 'B',
        'A', 'A', 'B', 'C', 'A',
        'B', 'A', 'B', 'A', 'C',
        'A', 'B'
    ]
})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사번      22 non-null     str
#  1   이름      22 non-null     str
#  2   부서      22 non-null     str
#  3   성별      22 non-null     str
#  4   나이      22 non-null     int64
#  5   연봉      22 non-null     int64
#  6   근속년수    22 non-null     int64
#  7   평가등급    22 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#               나이           연봉       근속년수
# count  22.000000    22.000000  22.000000
# mean   33.136364  5418.181818   7.136364
# std     6.073325  1290.122314   5.083076
# min    25.000000  3800.000000   1.000000
# 25%    28.250000  4325.000000   3.000000
# 50%    31.500000  5150.000000   5.500000
# 75%    37.500000  6250.000000  10.500000
# max    45.000000  8100.000000  18.000000

# %%
s= df["나이"]
s.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["성별"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='성별'>

# %%
#df["평가등급"].value_counts().plot(kind="bar")
df["평가등급"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
#df["근속년수"].plot(kind="pie")
df["근속년수"].plot(kind="hist",bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["연봉"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["부서"].value_counts().plot(kind="pie")
# Out:
# <Axes: >
