# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# 차트에 한글 깨지지 않도록 차트 폰트변경
plt.rcParams['font.family'] = 'Malgun Gothic'
# 차트에 "-"문자 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
from wordcloud import WordCloud
from collections import Counter

# %%
df = pd.read_excel("news1.xlsx")
df.head()
# Out:
#                                                  키워드
# 0  올가을,로맨스,김소현,책임집,케이팝,헌터스,케이팝,헌터스,주목,K팝,K드라마,K무비...
# 1  뉴스핌,마이,케이팝,스타,본선,라이브,시작,3일,10팀,공개,이지은,종합뉴스통신사,...
# 2  임정희,김보경,성료,합동,콘서트,히트곡,퍼레이드,공연,이지은,가수,임정희,김보경,합...
# 3  피프티피프티,엔터테크,GES,서울,홍보,대사,발탁,18일,위촉식,축하,무대,출격,피...
# 4  아이딧,의지,1주년,소감,팀명,세상,일문일답,그룹,아이딧,IDID,데뷔,소감,위딧,...

# %%
#키워드 추출

keywords= df["키워드"]
keywords.head()
# Out:
# 0    올가을,로맨스,김소현,책임집,케이팝,헌터스,케이팝,헌터스,주목,K팝,K드라마,K무비...
# 1    뉴스핌,마이,케이팝,스타,본선,라이브,시작,3일,10팀,공개,이지은,종합뉴스통신사,...
# 2    임정희,김보경,성료,합동,콘서트,히트곡,퍼레이드,공연,이지은,가수,임정희,김보경,합...
# 3    피프티피프티,엔터테크,GES,서울,홍보,대사,발탁,18일,위촉식,축하,무대,출격,피...
# 4    아이딧,의지,1주년,소감,팀명,세상,일문일답,그룹,아이딧,IDID,데뷔,소감,위딧,...
# Name: 키워드, dtype: str

# %%
text= ",".join(keywords)

# %%
print(len(text))
print(text[:500])
# Out:
# 563936
# 올가을,로맨스,김소현,책임집,케이팝,헌터스,케이팝,헌터스,주목,K팝,K드라마,K무비,K컬쳐,중심,별들,현장,사진,스타투데이,사진,뉴스레터,코너,드라마,연애,박사,배우,김소현,화이트,드레스,민트,스푼,청순,페미닌,정석,배우,김소현,성수동,행사,향수,브랜드,참석,미모,선사,이날,김소현,화이트,드레스,청순,분위기,완성,목선,홀터넥,스타일,화이트,원피스,취재진,심플,디자인,자연,플레어,실루엣,여성,분위기,어깨,라인,홀터넥,디자인,과도,노출,세련미,스타일링,포인트,스틸레토,민트,컬러,스틸레토,머리,발끝,화이트,통일,민트색,슈즈,매치,전체적,생기,화이트,파스텔,민트,조합,청량감,전체적,액세서리,최소화,귀걸이,반지,정도,생머리,자연,드레스,특유,분위기,미니멀,스타일링,드레스,실루엣,인물,분위기,강조,김소현,공개,드라마,연애,박사,시청자들,올가을,로맨스,배우,김소현,모습,사진,김소현,입장,순백,여신,김소현,미모,장인,올가을,예약,로맨스,장인,꽃받침,손인사,김소현,볼콕,매력,로맨스,비율,김소현,김소

# %%
# text를 리스트로 변경(수치 탐색용)

words= text.split(",") 
print("리스트의 사이즈: ",len(words))
# Out:
# 리스트의 사이즈:  150625

# %%
# 키워드별 갯수

words_count= Counter(words)
print(words_count.most_common(20)) # 키워드 갯수가 가장 많은 20등까지
# Out:
# [('영화', 946), ('한국', 923), ('케이팝', 876), ('음악', 836), ('공연', 773), ('문화', 694), ('글로벌', 647), ('세계', 639), ('축제', 637), ('미국', 582), ('콘텐츠', 533), ('무대', 525), ('앨범', 510), ('차트', 457), ('참여', 455), ('대표', 446), ('진행', 438), ('영화제', 426), ('행사', 417), ('서울', 406)]

# %%
# WordCloud 생성
wordcloud = WordCloud(
    font_path="C:/Windows/Fonts/malgun.ttf",
    width=800,
    height=500,
    background_color="white",
    stopwords = set()
).generate_from_frequencies(words_count)

# 출력
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df = pd.read_excel("news2.xlsx")
df.head()
# Out:
#                                                  키워드
# 0  AI,위험,vs,주머니,사정,뉴스in뉴스,앵커,AI,산업,국면,AI,속도,AI,서영...
# 1  속도조절론,연일,AI,속도,조절,트럼프,대선,겨냥,AI,대책,회의,민주당,선거,쟁점...
# 2  6달러,디젤,전쟁,우크라,에너지,휴전,조건부,수용,러시아,트럼프,공격,중단,요구,환...
# 3  트럼프,7배,1위,세계,연봉,지도자,로런스,공직자,보수,개편,5년,급여,64%,인상...
# 4  폐쇄,사우디,송유관,국제,유가,상승,105달러,앵커,격화,중동,전쟁,세계,최대,산유...

# %%
keywords= df["키워드"]
keywords.head()
# Out:
# 0    AI,위험,vs,주머니,사정,뉴스in뉴스,앵커,AI,산업,국면,AI,속도,AI,서영...
# 1    속도조절론,연일,AI,속도,조절,트럼프,대선,겨냥,AI,대책,회의,민주당,선거,쟁점...
# 2    6달러,디젤,전쟁,우크라,에너지,휴전,조건부,수용,러시아,트럼프,공격,중단,요구,환...
# 3    트럼프,7배,1위,세계,연봉,지도자,로런스,공직자,보수,개편,5년,급여,64%,인상...
# 4    폐쇄,사우디,송유관,국제,유가,상승,105달러,앵커,격화,중동,전쟁,세계,최대,산유...
# Name: 키워드, dtype: str

# %%
text= ",".join(keywords)

# %%
print(len(text))
print(text[:300])
# Out:
# 2757035
# AI,위험,vs,주머니,사정,뉴스in뉴스,앵커,AI,산업,국면,AI,속도,AI,서영민,속도,얘기,주목,우선,지난주,앤트로픽,퇴사,인류학자,주목,10년,인간,AI,멸종,충격,발언,AI,바이러스,설계,의견,직장,사람,경고,기름,회사,최고,경영자,앵커,앤트로픽,최고,경영자,다리오,아모데이,발언,온라인,홈페이지,장문,속도,감당,올여름,AI,인간,도움,성능,향상,속도,AI,인간,지시,거부,AI,진짜,위험,그동안,고백,아모데이,앤트로픽,CEO,실질적,위험,존재,업계,오랫동안,AI,위험성,사람들,생각,앵커,구체적,대목,위험성,오픈AI,얼마,모델

# %%
words= text.split(",") 
print("리스트의 사이즈: ",len(words))
# Out:
# 리스트의 사이즈:  781869

# %%
words_count= Counter(words)
print(words_count.most_common(20)) # 키워드 갯수가 가장 많은 20등까지
# Out:
# [('미국', 17868), ('트럼프', 14513), ('대통령', 12920), ('AI', 7088), ('이란', 6120), ('달러', 4592), ('전쟁', 4059), ('정부', 3870), ('중국', 3866), ('파병', 3347), ('선거', 3085), ('한국', 3046), ('금리', 2879), ('도널드', 2782), ('공격', 2782), ('시장', 2776), ('호르무즈', 2740), ('캐나다', 2588), ('공화당', 2404), ('투자', 2398)]

# %%
# WordCloud 생성
wordcloud = WordCloud(
    font_path="C:/Windows/Fonts/malgun.ttf",
    width=800,
    height=500,
    background_color="white",
    stopwords = set()
).generate(text)

# 출력
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
