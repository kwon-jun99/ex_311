# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# 차트에 한글 깨지지 않도록 차트 폰트변경
plt.rcParams['font.family'] = 'Malgun Gothic'
# 차트에 "-"문자 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

# %%
img1= mping.imread("cat.jpg")
img2= mping.imread("car.jpg")
img3= mping.imread("dog.jpg")
img4= mping.imread("flower.jpg")
print(img1,img2,img3,img4)
# Out:
# [[[254 254 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [249 245 246]
#   [249 247 250]
#   [255 254 255]]
#
#  [[254 254 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 254 255]
#   [254 252 255]
#   [255 254 255]]
#
#  [[254 254 255]
#   [255 255 255]
#   [254 254 255]
#   ...
#   [255 254 253]
#   [255 253 255]
#   [253 251 255]]
#
#  ...
#
#  [[255 253 255]
#   [255 253 253]
#   [255 251 247]
#   ...
#   [255 253 249]
#   [253 249 246]
#   [248 247 245]]
#
#  [[255 250 255]
#   [255 254 255]
#   [255 253 250]
#   ...
#   [255 254 251]
#   [249 248 246]
#   [250 249 247]]
#
#  [[254 251 255]
#   [255 254 255]
#   [252 251 249]
#   ...
#   [255 254 255]
#   [252 250 251]
#   [254 252 253]]] [[[254 255 253]
#   [254 255 251]
#   [253 254 249]
#   ...
#   [255 255 255]
#   [255 254 255]
#   [254 255 255]]
#
#  [[251 253 250]
#   [251 253 248]
#   [254 255 249]
#   ...
#   [241 239 242]
#   [245 244 249]
#   [254 255 255]]
#
#  [[250 252 247]
#   [251 253 248]
#   [253 254 248]
#   ...
#   [255 255 253]
#   [254 254 254]
#   [254 255 255]]
#
#  ...
#
#  [[253 255 254]
#   [253 255 254]
#   [253 255 254]
#   ...
#   [255 255 251]
#   [254 254 252]
#   [253 253 251]]
#
#  [[238 240 239]
#   [238 240 239]
#   [238 240 239]
#   ...
#   [242 241 237]
#   [240 240 238]
#   [240 240 238]]
#
#  [[191 191 193]
#   [191 191 193]
#   [191 191 193]
#   ...
#   [195 194 192]
#   [193 193 191]
#   [193 193 191]]] [[[253 242 248]
#   [255 250 255]
#   [255 249 255]
#   ...
#   [255 255 255]
#   [249 249 249]
#   [255 255 255]]
#
#  [[255 244 250]
#   [255 252 255]
#   [253 247 251]
#   ...
#   [247 247 247]
#   [251 251 251]
#   [250 250 250]]
#
#  [[246 237 242]
#   [255 252 255]
#   [255 253 255]
#   ...
#   [248 248 246]
#   [255 255 253]
#   [255 255 253]]
#
#  ...
#
#  [[245 245 245]
#   [254 254 254]
#   [254 254 252]
#   ...
#   [252 253 248]
#   [245 245 243]
#   [246 244 247]]
#
#  [[247 247 247]
#   [253 253 253]
#   [255 255 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 254 255]]
#
#  [[248 248 248]
#   [250 250 250]
#   [255 255 255]
#   ...
#   [249 248 253]
#   [251 250 255]
#   [252 249 255]]] [[[241 250 249]
#   [249 255 255]
#   [249 253 254]
#   ...
#   [254 253 255]
#   [254 253 255]
#   [255 253 255]]
#
#  [[251 255 255]
#   [251 255 255]
#   [250 254 255]
#   ...
#   [255 255 255]
#   [254 253 255]
#   [250 249 255]]
#
#  [[249 253 254]
#   [245 249 250]
#   [251 252 254]
#   ...
#   [235 236 231]
#   [252 252 252]
#   [253 253 255]]
#
#  ...
#
#  [[255 254 255]
#   [253 253 255]
#   [252 252 250]
#   ...
#   [255 255 246]
#   [255 255 250]
#   [254 253 249]]
#
#  [[255 254 255]
#   [253 252 255]
#   [254 254 254]
#   ...
#   [255 254 250]
#   [248 247 245]
#   [247 246 244]]
#
#  [[253 252 255]
#   [253 252 255]
#   [254 254 255]
#   ...
#   [255 254 252]
#   [255 253 254]
#   [255 253 254]]]

# %%
fig= plt.figure()
print(fig)
# Out:
# Figure(640x480)

# %%
# 생성된 fig 4등분(2X2)

axes1= fig.add_subplot(2,2,1)
axes2= fig.add_subplot(2,2,2)
axes3= fig.add_subplot(2,2,3)
axes4= fig.add_subplot(2,2,4)

# %%
axes1.imshow(img1)
axes2.imshow(img2)
axes3.imshow(img3)
axes4.imshow(img4)

axes1.axis("off")
axes2.axis("off")
axes3.axis("off")
axes4.axis("off")

axes1.set_title("Cat")
axes2.set_title("Car")
axes3.set_title("Dog")
axes4.set_title("Flower")

fig

# %%
x1 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

x2 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]

x3 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
import numpy as np

# 4개의 데이터셋을 하나로 묶기
datasets = [
    (x1, y1),
    (x2, y2),
    (x3, y3),
    (x4, y4)
]


# 데이터셋별 통계량 계산
for i, (x, y) in enumerate(datasets, start=1):

    # 리스트를 NumPy 배열로 변환
    x = np.array(x)
    y = np.array(y)

    # 평균
    x_mean = np.mean(x)
    y_mean = np.mean(y)

    # 분산
    # ddof=1 → 표본분산
    x_var = np.var(x, ddof=1)
    y_var = np.var(y, ddof=1)

    # 상관계수
    correlation = np.corrcoef(x, y)[0, 1]

    # 회귀선
    # y = a*x + b
    # a = 기울기, b = 절편
    a, b = np.polyfit(x, y, 1)

    print(f"\n[Dataset {i}]")

    print(f"x 평균     : {x_mean:.2f}")
    print(f"y 평균     : {y_mean:.2f}")

    print(f"x 분산     : {x_var:.2f}")
    print(f"y 분산     : {y_var:.2f}")

    print(f"상관계수   : {correlation:.2f}")

    print(f"회귀선 기울기 : {a:.2f}")
    print(f"회귀선 절편   : {b:.2f}")

    print(f"회귀식     : y = {a:.2f}x + {b:.2f}")
# Out:
# [Dataset 1]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.13
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 2]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.13
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 3]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.12
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00
#
# [Dataset 4]
# x 평균     : 9.00
# y 평균     : 7.50
# x 분산     : 11.00
# y 분산     : 4.12
# 상관계수   : 0.82
# 회귀선 기울기 : 0.50
# 회귀선 절편   : 3.00
# 회귀식     : y = 0.50x + 3.00

# %%
# 전체 그래프를 담을 큰 도화지(Figure)를 생성한다.
fig = plt.figure(figsize=(10, 8))

axes1 = fig.add_subplot(2, 2, 1)
axes1.scatter(x1, y1)
axes1.set_title("Dataset 1")

axes2 = fig.add_subplot(2, 2, 2)
axes2.scatter(x2, y2)
axes2.set_title("Dataset 2")

axes3 = fig.add_subplot(2, 2, 3)
axes3.scatter(x3, y3)
axes3.set_title("Dataset 3")

axes4 = fig.add_subplot(2, 2, 4)
axes4.scatter(x4, y4)
axes4.set_title("Dataset 4")

fig.tight_layout()
plt.show()
