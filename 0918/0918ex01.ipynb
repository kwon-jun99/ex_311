# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
arr=np.array([60, 62, 65, 67, 68, 70, 72, 75, 78, 95, 200])
print(arr)
print(type(arr))
# Out:
# [ 60  62  65  67  68  70  72  75  78  95 200]
# <class 'numpy.ndarray'>

# %%
s= pd.Series(arr)
print(s)
# Out:
# 0      60
# 1      62
# 2      65
# 3      67
# 4      68
# 5      70
# 6      72
# 7      75
# 8      78
# 9      95
# 10    200
# dtype: int64

# %%
Q1= s.quantile(0.25)
Q3= s.quantile(0.75)
median= s.median()
print(Q1,median,Q3)

IQR= Q3-Q1
print("IQR:",IQR)

upper= Q3 + (IQR*1.5)
lower= Q1 - (IQR*1.5)
print("upper:",upper)
print("lower:",lower)
# Out:
# 66.0 70.0 76.5
# IQR: 10.5
# upper: 92.25
# lower: 50.25

# %%
fig= plt.figure()
axes1= fig.add_subplot(1,1,1)
sns.boxplot(s)
plt.show()

# %%
mean = s.mean()
print("mean",mean)
# Out:
# mean 82.9090909090909

# %%
var=round(arr.var(),1)
std=round(arr.std(),1)
print("var",var,"std:",std)
# Out:
# var 1453.4 std: 38.1

# %%
Z_score=(s-mean) / std
print(Z_score.abs()>3)

fig= plt.figure()
axes1=fig.add_subplot(1,1,1)
sns.histplot(s)
plt.show()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
arr=np.array([30, 35, 68, 72, 75, 70, 65, 78, 82, 74, 69, 71,76, 80, 73, 67, 77, 84, 79, 72, 66, 81,
70, 75, 83, 68, 74, 78, 71, 85, 76, 69,73, 80, 77, 72, 68, 82, 75, 70, 79, 74,67, 81, 76, 73, 78, 69, 84, 71, 75, 80,
72, 77, 68, 74, 82, 79, 70, 76, 85, 73,69, 81, 75, 78, 72, 67, 80, 74, 77, 71,83, 76, 70, 79, 73, 68, 82, 75, 71, 78,74, 80, 69, 77, 72, 81, 76, 70, 84, 73,
75, 79, 68, 82, 74,115, 120, 125])
print(arr)
print(type(arr))
# Out:
# [ 30  35  68  72  75  70  65  78  82  74  69  71  76  80  73  67  77  84
#   79  72  66  81  70  75  83  68  74  78  71  85  76  69  73  80  77  72
#   68  82  75  70  79  74  67  81  76  73  78  69  84  71  75  80  72  77
#   68  74  82  79  70  76  85  73  69  81  75  78  72  67  80  74  77  71
#   83  76  70  79  73  68  82  75  71  78  74  80  69  77  72  81  76  70
#   84  73  75  79  68  82  74 115 120 125]
# <class 'numpy.ndarray'>

# %%
s= pd.Series(arr)
print(s)
# Out:
# 0      30
# 1      35
# 2      68
# 3      72
# 4      75
#      ...
# 95     82
# 96     74
# 97    115
# 98    120
# 99    125
# Length: 100, dtype: int64

# %%
Q1= s.quantile(0.25)
Q3= s.quantile(0.75)
median= s.median()
print(Q1,median,Q3)

IQR= Q3-Q1
print("IQR:",IQR)

upper= Q3 + (IQR*1.5)
lower= Q1 - (IQR*1.5)
print("upper:",upper)
print("lower:",lower)
# Out:
# 71.0 75.0 79.0
# IQR: 8.0
# upper: 91.0
# lower: 59.0

# %%
fig= plt.figure()
axes1= fig.add_subplot(1,1,1)
sns.boxplot(s)
plt.show()

# %%
mean = s.mean()
print("mean",mean)
# Out:
# mean 75.46

# %%
var=round(arr.var(),1)
std=round(arr.std(),1)
print("var",var,"std:",std)
# Out:
# var 121.3 std: 11.0

# %%
Z_score=(s-mean) / std
print(Z_score.abs()>3)

fig= plt.figure()
axes1=fig.add_subplot(1,1,1)
sns.histplot(s)
plt.show()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97     True
# 98     True
# 99     True
# Length: 100, dtype: bool
